# %% [markdown]
# <a href="https://colab.research.google.com/github/DCI-alxogm/ml2023-DavRo24/blob/main/Ago11-12/Tarea2/Ejercicio-y-tarea18-08.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
datos = np.loadtxt("olympic100m_men.txt", delimiter=',').T
x=datos[0]
y=datos[1]
plt.scatter(x,y)

# %%
slope = ((np.mean(x) * np.mean(y)) - np.mean(x * y)) / ((np.mean(x) ** 2) - np.mean(x ** 2))
intercept = np.mean(y) - slope * np.mean(x)

# Crear puntos para la línea de regresión
x_regression = np.linspace(min(x), max(x), 100)
y_regression = slope * x_regression + intercept

# Graficar los puntos de datos y la línea de regresión
plt.scatter(x, y, label='Datos')
plt.plot(x_regression, y_regression, color='red', label='Regresión lineal')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Regresión Lineal por Mínimos Cuadrados')
plt.legend()
plt.grid(True)
plt.show()

# %%
datos1 = np.loadtxt("olympic400m_men.txt", delimiter=',').T
a=datos[0]
b=datos[1]
plt.scatter(a,b)

# %%
# Calcular la pendiente (coeficiente angular)
pendiente = ((np.mean(a) * np.mean(b)) - np.mean(a * b)) / ((np.mean(a) ** 2) - np.mean(a ** 2))

# Calcular la ordenada al origen
ordenada = np.mean(b) - pendiente * np.mean(a)

# Crear puntos para la línea de regresión
a_regression = np.linspace(min(a), max(a), 100)
b_regression = pendiente * a_regression + ordenada

# Graficar los puntos de datos y la línea de regresión
plt.scatter(a, b, label='Datos')
plt.plot(a_regression, b_regression, color='red', label='Regresión lineal')
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Regresión Lineal por Mínimos Cuadrados')
plt.legend()
plt.grid(True)
plt.show()
